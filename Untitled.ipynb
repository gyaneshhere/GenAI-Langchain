# %%
import requests
from bs4 import BeautifulSoup


vgm_url = 'https://www.invitedclubs.com/find-a-club'
html_text = requests.get(vgm_url).text
soup = BeautifulSoup(html_text, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=10" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Find Invited Clubs in Your Area | invitedclubs.com</title>
# <meta content="Find Invited Clubs in Your Area | invitedclubs.com" property="og:title"/>
# <meta content="Find Invited Clubs in Your Area | invitedclubs.com" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="Find Invited Clubs in Your Area | invitedclubs.com" name="description"/>
# <meta content="Find Invited Clubs in Your Area | invitedclubs.com" property="og:description"/>
# <meta content="Find Invited Clubs in Your Area | invitedclubs.com" property="twitter:description"/>
# <meta content="https://www.invitedclubs.com/find-a-club" property="og:url"/>
# <link href="https://www.invitedclubs.com/find-a-club" rel="canonical"/>
# <meta content="summary" property="twitter:card"/>
# ...
